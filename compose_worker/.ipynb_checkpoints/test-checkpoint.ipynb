# %%
import os 
import tempfile 
from typing import Union, List
from output_data import handle_sbml_exception
from workers import VerificationWorker
import pandas as pd
import numpy as np


omex_job = {
  "job_id": "verification-utc_comparison_omex-1553bfd5-3135-4968-a24c-8e4909d73fd0",
  "status": "PENDING",
  "timestamp": "2024-09-05 16:41:58.904410",
  "path": "file_uploads/verification-utc_comparison_omex-1553bfd5-3135-4968-a24c-8e4909d73fd0/BIOMD0000000010.omex",
  "simulators": [
    "copasi",
    "tellurium"
  ],
}
omex_fp = '../model-examples/sbml-core/' + omex_job['path'].split('/')[-1]
s = omex_job['simulators']
out_dir = tempfile.mkdtemp()
w = VerificationWorker(omex_job)

# %%
from data_model import BiosimulationsRunOutputData
from io_worker import read_h5_reports
from importlib import import_module
from kisao import AlgorithmSubstitutionPolicy
from biosimulators_utils.config import Config
from io_worker import make_dir


def generate_biosimulator_utc_outputs(omex_fp: str, output_root_dir: str, simulators: list[str] = None, alg_policy="same_framework") -> dict:
    """Generate the outputs of the standard UTC simulators Copasi, Tellurium, and Amici from the
        biosimulators interface (exec_sedml_docs_in_combine_archive).
    """
    make_dir(output_root_dir)

    output_data = {}
    sims = simulators or ['amici', 'copasi', 'tellurium']  # ,'pysces']
    sim_config = Config(
        LOG=False,
        ALGORITHM_SUBSTITUTION_POLICY=AlgorithmSubstitutionPolicy[alg_policy.upper()],
        VERBOSE=False)
    for sim in sims:
        sim_output_dir = os.path.join(output_root_dir, f'{sim}_outputs')
        make_dir(sim_output_dir)
        try:
            module = import_module(name=f'biosimulators_{sim}.core')
            exec_func = getattr(module, 'exec_sedml_docs_in_combine_archive')
            sim_output_dir = os.path.join(output_root_dir, f'{sim}_outputs')
            if not os.path.exists(sim_output_dir):
                os.mkdir(sim_output_dir)

            # execute simulator-specific simulation
            exec_func(archive_filename=omex_fp, out_dir=sim_output_dir, config=sim_config)
            report_path = os.path.join(sim_output_dir, 'reports.h5')

            sim_data = read_h5_reports(report_path)
            data = sim_data.to_dict() if isinstance(sim_data, BiosimulationsRunOutputData) else sim_data
            print(f'{sim} data keys: {data.keys()}')
            output_data[sim] = data
        except:
            import traceback
            tb_str = traceback.format_exc()
            error_message = (
                f"Traceback:\n{tb_str}"
            )
            output_data[sim] = {'error': error_message}

    return output_data


utc_outputs = generate_biosimulator_utc_outputs(omex_fp, out_dir, s)
# Out:
# Archive contains 1 SED-ML documents with 2 models, 2 simulations, 2 tasks, 3 reports, and 2 plots:
#   BIOMD0000000010_url.sedml:
#     Tasks (2):
#       task_fig2a
#       task_fig2b
#     Reports (3):
#       autogen_report_for_task_fig2a: 20 data sets
#       report_2: 3 data sets
#       report_3: 3 data sets
#     Plots (2):
#       plot_0: 2 curves
#       plot_1: 2 curves
#
# Executing SED-ML file 1: BIOMD0000000010_url.sedml ...
#   Found 2 tasks and 5 outputs:
#     Tasks:
#       `task_fig2a`
#       `task_fig2b`
#     Outputs:
#       `autogen_report_for_task_fig2a`
#       `plot_0`
#       `plot_1`
#       `report_2`
#       `report_3`
#   Executing task 1: `task_fig2a`
#     Executing simulation ... succeeded
#     Generating 5 outputs ...
#       Generating output 1: `plot_0` ...
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# COMBINE/OMEX archive has warnings.
#   - The manifest does not include its parent COMBINE/OMEX archive. Manifests should include their parent COMBINE/OMEX archives.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: SedmlFeatureNotSupportedWarning:
#
# `/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/tmpo6tkwe54/BIOMD0000000010_url.sedml` is encoded using L1V4. Only a few features introduced after L1V3 are supported. Most newer features, such as finer stylistic control of plots and parameter estimation, are not yet supported.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# The SED document is potentially incorrect.
#   - This tool validates XPaths for model changes and variables against their unmodified target models. As a result, this tool does not fully validate these XPaths. These XPaths could be invalidated by changes to their target models.
#   - Model `kholodenko` has warnings.
#     - The model file `BIOMD0000000010_url.xml` has warnings.
#       - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#         - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#            The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#       - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#         - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#            The <parameter> with the id 'V1' does not have a 'units' attribute.
#   - Data generator `plot_1_0_1` has warnings.
#     - Variable `task_fig2b_____MAPK_PP` has warnings.
#       - XPath could not be validated.
#   - Data generator `plot_1_1_1` has warnings.
#     - Variable `task_fig2b_____MAPK` has warnings.
#       - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# The COMBINE/OMEX archive has warnings.
#   - The SED-ML file at location `BIOMD0000000010_url.sedml` has warnings.
#     - This tool validates XPaths for model changes and variables against their unmodified target models. As a result, this tool does not fully validate these XPaths. These XPaths could be invalidated by changes to their target models.
#     - Model `kholodenko` has warnings.
#       - The model file `BIOMD0000000010_url.xml` has warnings.
#         - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#           - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#              The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#         - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#           - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#              The <parameter> with the id 'V1' does not have a 'units' attribute.
#     - Data generator `plot_1_0_1` has warnings.
#       - Variable `task_fig2b_____MAPK_PP` has warnings.
#         - XPath could not be validated.
#     - Data generator `plot_1_1_1` has warnings.
#       - Variable `task_fig2b_____MAPK` has warnings.
#         - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: SedmlFeatureNotSupportedWarning:
#
# `/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/tmpo6tkwe54/BIOMD0000000010_url.sedml` is encoded using L1V4. Only a few features introduced after L1V3 are supported. Most newer features, such as finer stylistic control of plots and parameter estimation, are not yet supported.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# The SED document is potentially incorrect.
#   - This tool validates XPaths for model changes and variables against their unmodified target models. As a result, this tool does not fully validate these XPaths. These XPaths could be invalidated by changes to their target models.
#   - Data generator `plot_1_0_1` has warnings.
#     - Variable `task_fig2b_____MAPK_PP` has warnings.
#       - XPath could not be validated.
#   - Data generator `plot_1_1_1` has warnings.
#     - Variable `task_fig2b_____MAPK` has warnings.
#       - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# - Variable `auto_dg_for_task_fig2a_J3__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J2__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J4__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J7__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_uVol__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J5__x` has warnings.
#   - XPath could not be validated.
# - Variable `task_fig2a_____MAPK` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKKK__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J0__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J6__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J1__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKK__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKKK_P__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKK_PP__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MAPK_P__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKK_P__x` has warnings.
#   - XPath could not be validated.
# - Variable `task_fig2a_____MAPK_PP` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J9__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J8__x` has warnings.
#   - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# Model `kholodenko` may be invalid.
#   - The model file `/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/tmpo6tkwe54/BIOMD0000000010_url.xml` has warnings.
#     - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#       - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#          The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#     - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#       - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#          The <parameter> with the id 'V1' does not have a 'units' attribute.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/kisao/utils.py:518: AlgorithmSubstitutedWarning:
#
# 'LSODA/LSODAR hybrid method' (KISAO_0000560) will be substituted for 'ODE solver' (KISAO_0000694) at substitution policy 'SAME_FRAMEWORK'.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#  succeeded
#       Generating output 2: `plot_1` ... queued
#       Generating output 3: `report_2` ... succeeded
#       Generating output 4: `report_3` ... queued
#       Generating output 5: `autogen_report_for_task_fig2a` ... succeeded
#   Executing task 2: `task_fig2b`
#     Executing simulation ... succeeded
#     Generating 5 outputs ...
#       Generating output 1: `plot_0` ...
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the X axis because the X data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# Curves have inconsistent x axis scales. All curves will be plotted in linear scale.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# Curves have inconsistent y axis scales. All curves will be plotted in linear scale.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# - Variable `task_fig2b_____MAPK` has warnings.
#   - XPath could not be validated.
# - Variable `task_fig2b_____MAPK_PP` has warnings.
#   - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# Model `kholodenko_b` may be invalid.
#   - The model file `/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/tmpo6tkwe54/tmpktkto2fl.xml` has warnings.
#     - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#       - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#          The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#     - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#       - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#          The <parameter> with the id 'V1' does not have a 'units' attribute.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/kisao/utils.py:518: AlgorithmSubstitutedWarning:
#
# 'LSODA/LSODAR hybrid method' (KISAO_0000560) will be substituted for 'ODE solver' (KISAO_0000694) at substitution policy 'SAME_FRAMEWORK'.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#  succeeded
#       Generating output 2: `plot_1` ... succeeded
#       Generating output 3: `report_2` ... succeeded
#       Generating output 4: `report_3` ... succeeded
#       Generating output 5: `autogen_report_for_task_fig2a` ... succeeded
#
# Bundling outputs ...
# Cleaning up ...
# copasi data keys: dict_keys(['Time', 'MAPK_PP', 'MAPK', 'MKKK', 'MKKK_P', 'MKK', 'MKK_P', 'MKK_PP', 'MAPK_P', 'uVol', 'J0', 'J1', 'J2', 'J3', 'J4', 'J5', 'J6', 'J7', 'J8', 'J9', 'task_fig2a.time/60', 'task_fig2b.time/60', 'task_fig2a.MAPK_PP', 'task_fig2a.MAPK', 'task_fig2b.MAPK_PP', 'task_fig2b.MAPK'])
# Archive contains 1 SED-ML documents with 2 models, 2 simulations, 2 tasks, 3 reports, and 2 plots:
#   BIOMD0000000010_url.sedml:
#     Tasks (2):
#       task_fig2a
#       task_fig2b
#     Reports (3):
#       autogen_report_for_task_fig2a: 20 data sets
#       report_2: 3 data sets
#       report_3: 3 data sets
#     Plots (2):
#       plot_0: 2 curves
#       plot_1: 2 curves
#
# Executing SED-ML file 1: BIOMD0000000010_url.sedml ...
#   Found 2 tasks and 5 outputs:
#     Tasks:
#       `task_fig2a`
#       `task_fig2b`
#     Outputs:
#       `autogen_report_for_task_fig2a`
#       `plot_0`
#       `plot_1`
#       `report_2`
#       `report_3`
#   Executing task 1: `task_fig2a`
#     Executing simulation ... succeeded
#     Generating 5 outputs ...
#       Generating output 1: `plot_0` ...
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# COMBINE/OMEX archive has warnings.
#   - The manifest does not include its parent COMBINE/OMEX archive. Manifests should include their parent COMBINE/OMEX archives.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: SedmlFeatureNotSupportedWarning:
#
# `/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/tmpqomurdjh/BIOMD0000000010_url.sedml` is encoded using L1V4. Only a few features introduced after L1V3 are supported. Most newer features, such as finer stylistic control of plots and parameter estimation, are not yet supported.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# The SED document is potentially incorrect.
#   - This tool validates XPaths for model changes and variables against their unmodified target models. As a result, this tool does not fully validate these XPaths. These XPaths could be invalidated by changes to their target models.
#   - Model `kholodenko` has warnings.
#     - The model file `BIOMD0000000010_url.xml` has warnings.
#       - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#         - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#            The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#       - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#         - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#            The <parameter> with the id 'V1' does not have a 'units' attribute.
#   - Data generator `plot_1_0_1` has warnings.
#     - Variable `task_fig2b_____MAPK_PP` has warnings.
#       - XPath could not be validated.
#   - Data generator `plot_1_1_1` has warnings.
#     - Variable `task_fig2b_____MAPK` has warnings.
#       - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# The COMBINE/OMEX archive has warnings.
#   - The SED-ML file at location `BIOMD0000000010_url.sedml` has warnings.
#     - This tool validates XPaths for model changes and variables against their unmodified target models. As a result, this tool does not fully validate these XPaths. These XPaths could be invalidated by changes to their target models.
#     - Model `kholodenko` has warnings.
#       - The model file `BIOMD0000000010_url.xml` has warnings.
#         - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#           - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#              The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#         - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#           - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#              The <parameter> with the id 'V1' does not have a 'units' attribute.
#     - Data generator `plot_1_0_1` has warnings.
#       - Variable `task_fig2b_____MAPK_PP` has warnings.
#         - XPath could not be validated.
#     - Data generator `plot_1_1_1` has warnings.
#       - Variable `task_fig2b_____MAPK` has warnings.
#         - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# The SED document is potentially incorrect.
#   - This tool validates XPaths for model changes and variables against their unmodified target models. As a result, this tool does not fully validate these XPaths. These XPaths could be invalidated by changes to their target models.
#   - Data generator `plot_1_0_1` has warnings.
#     - Variable `task_fig2b_____MAPK_PP` has warnings.
#       - XPath could not be validated.
#   - Data generator `plot_1_1_1` has warnings.
#     - Variable `task_fig2b_____MAPK` has warnings.
#       - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# - Variable `auto_dg_for_task_fig2a_MKK_P__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_uVol__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKK__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKKK__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J6__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J0__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J5__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKKK_P__x` has warnings.
#   - XPath could not be validated.
# - Variable `task_fig2a_____MAPK` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MAPK_P__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J8__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J3__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J7__x` has warnings.
#   - XPath could not be validated.
# - Variable `task_fig2a_____MAPK_PP` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J4__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J2__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J9__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_J1__x` has warnings.
#   - XPath could not be validated.
# - Variable `auto_dg_for_task_fig2a_MKK_PP__x` has warnings.
#   - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# Model `kholodenko` may be invalid.
#   - The model file `/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/tmpqomurdjh/BIOMD0000000010_url.xml` has warnings.
#     - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#       - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#          The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#     - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#       - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#          The <parameter> with the id 'V1' does not have a 'units' attribute.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/kisao/utils.py:518: AlgorithmSubstitutedWarning:
#
# 'CVODE' (KISAO_0000019) will be substituted for 'ODE solver' (KISAO_0000694) at substitution policy 'SAME_FRAMEWORK'.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#  succeeded
#       Generating output 2: `plot_1` ... queued
#       Generating output 3: `report_2` ... succeeded
#       Generating output 4: `report_3` ... queued
#       Generating output 5: `autogen_report_for_task_fig2a` ... succeeded
#   Executing task 2: `task_fig2b`
#     Executing simulation ... failed
#     Generating 5 outputs ...
#       Generating output 1: `plot_0` ... succeeded
#       Generating output 2: `plot_1` ... queued
#       Generating output 3: `report_2` ... succeeded
#       Generating output 4: `report_3` ... queued
#       Generating output 5: `autogen_report_for_task_fig2a` ...
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the X axis because the X data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# Curves have inconsistent x axis scales. All curves will be plotted in linear scale.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# Curves have inconsistent y axis scales. All curves will be plotted in linear scale.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# - Variable `task_fig2b_____MAPK` has warnings.
#   - XPath could not be validated.
# - Variable `task_fig2b_____MAPK_PP` has warnings.
#   - XPath could not be validated.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: BioSimulatorsWarning:
#
# Model `kholodenko_b` may be invalid.
#   - The model file `/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/tmpqomurdjh/BIOMD0000000010_url.xml` has warnings.
#     - 10 warnings of type SBML unit consistency (99505). The following is the first warning at line 236, column 8:
#       - In situations where a mathematical expression contains literal numbers or parameters whose units have not been declared, it is not possible to verify accurately the consistency of the units in the expression.
#          The units of the <kineticLaw> <math> expression 'uVol * V1 * MKKK / ((1 + pow(MAPK_PP / Ki, n)) * (K1 + MKKK))' cannot be fully checked. Unit consistency reported as either no errors or further unit errors related to this object may not be accurate.
#     - 22 warnings of type Modeling practice (80701). The following is the first warning at line 270, column 12:
#       - As a principle of best modeling practice, the units of a <parameter> should be declared rather than be left undefined. Doing so improves the ability of software to check the consistency of units and helps make it easier to detect potential errors in models.
#          The <parameter> with the id 'V1' does not have a 'units' attribute.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/kisao/utils.py:518: AlgorithmSubstitutedWarning:
#
# 'CVODE' (KISAO_0000019) will be substituted for 'ODE solver' (KISAO_0000694) at substitution policy 'SAME_FRAMEWORK'.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the X axis because the X data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# A title could not be inferred for the Y axis because the Y data generators have inconsistent names.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# Curves have inconsistent x axis scales. All curves will be plotted in linear scale.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: IllogicalVizWarning:
#
# Curves have inconsistent y axis scales. All curves will be plotted in linear scale.
#
# /Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/warnings.py:31: StandardOutputNotLoggedWarning:
#
# Standard output and error could not be logged because capturer is not installed. To install capturer, install BioSimulators utils with the `logging` option (`pip install biosimulators-utils[logging]`).
#  succeeded
#
# Bundling outputs ...
# Cleaning up ...

# %%
utc_outputs['tellurium']
# Out:
# {'error': 'Traceback:\nTraceback (most recent call last):\n  File "/var/folders/yy/8crj8x7x5_3b86f0js6_0bn00000gr/T/ipykernel_46690/1347367769.py", line 32, in generate_biosimulator_utc_outputs\n    exec_func(archive_filename=omex_fp, out_dir=sim_output_dir, config=sim_config)\n  File "/Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_tellurium/core.py", line 85, in exec_sedml_docs_in_combine_archive\n    return exec_sedml_docs_in_archive(\n  File "/Users/alexanderpatrie/Library/Caches/pypoetry/virtualenvs/bio-compose-server-lb7k8x6F-py3.10/lib/python3.10/site-packages/biosimulators_utils/combine/exec.py", line 325, in exec_sedml_docs_in_archive\n    raise exception\nbiosimulators_utils.combine.exceptions.CombineArchiveExecutionError: The COMBINE/OMEX did not execute successfully:\n\n  The SED document did not execute successfully:\n  \n    Unable to process a change to model \'kholodenko_b\' with the target /sbml:sbml/sbml:model/sbml:listOfReactions/sbml:reaction[@id=\'J0\']/sbml:kineticLaw/sbml:listOfParameters/sbml:parameter[@id=\'n\']/@value because changing local parameters is not yet implemented.\n'}

# %%
def _generate_species_comparison_matrix(
        self,
        outputs: Union[np.ndarray, List[np.ndarray]],
        simulators: List[str],
        method: Union[str, any] = 'proximity',
        rtol: float = None,
        atol: float = None,
        ground_truth: np.ndarray = None
) -> pd.DataFrame:
    """Generate a Mean Squared Error comparison matrix of arr1 and arr2, indexed by simulators by default,
        or an AllClose Tolerance routine result if `method` is set to `proximity`.
        Args:
            outputs: list of output arrays.
            simulators: list of simulator names.
            method: pass one of either: `mse` to perform a mean-squared error calculation
                or `proximity` to perform a pair-wise proximity tolerance test using `np.allclose(outputs[i], outputs[i+1])`.
            rtol:`float`: relative tolerance for comparison if `proximity` is used.
            atol:`float`: absolute tolerance for comparison if `proximity` is used.
            ground_truth: If passed, this value is compared against each simulator in simulators. Currently, this
                field is agnostic to any verified/validated source, and we trust that the user has verified it. Defaults
                to `None`.
        Returns:
            Pandas dataframe representing a comparison matrix where `i` and `j` are both indexed by the
                simulators involved. The aforementioned simulators involved will also include the `ground_truth` value
                within the indices if one is passed.
    """
    # TODO: implement the ground truth
    _simulators = simulators.copy()
    _outputs = outputs.copy()
    if isinstance(_outputs, np.ndarray):
        _outputs = _outputs.tolist()
    if ground_truth is not None:
        _simulators.append('expected_results')
        _outputs.append(ground_truth)
    use_tol_method = method.lower() == 'proximity'
    matrix_dtype = np.float64 if not use_tol_method else bool
    num_simulators = len(_simulators)
    mse_matrix = np.zeros((num_simulators, num_simulators), dtype=matrix_dtype)
    # fill the matrices with the calculated values
    for i in range(len(_simulators)):
        for j in range(i, len(_simulators)):
            try:
                output_i = _outputs[i]
                output_j = _outputs[j]
                method_type = method.lower()
                if not isinstance(output_i, str) and not isinstance(output_j, str):
                    result = self.calculate_mse(output_i, output_j) if method_type == 'mse' else self.compare_arrays(arr1=output_i, arr2=output_j, rtol=rtol, atol=atol)
                    mse_matrix[i, j] = result
            except ValueError:
                error = handle_sbml_exception()
                mse_matrix[i, j] = error
            if i != j:
                mse_matrix[j, i] = mse_matrix[i, j]
    return pd.DataFrame(mse_matrix, index=_simulators, columns=_simulators)


def _get_output_stack(outputs: dict, spec_id: str) -> np.ndarray:
    output_stack = []
    for sim_name in outputs.keys():
        sim_data = outputs[sim_name]
        if isinstance(sim_data, dict):
            for spec_name in sim_data.keys():
                if spec_name == spec_id:
                    print(f'Data found for {spec_name} in {sim_name} results')
                    output_stack.append(sim_data[spec_name])

    return np.stack(output_stack)


def get_output_stack(spec_name: str, output):
    # 2. in output_stack: return {simname: output}
    stack = {}
    for simulator_name in output.keys():
        spec_data = output[simulator_name].get(spec_name)
        if isinstance(spec_data, str):
            data = None
        else:
            data = spec_data

        stack[simulator_name] = data

    return stack


def _generate_omex_utc_species_comparison(self, output_data, species_name, simulators, ground_truth=None, rTol=None, aTol=None):
    # extract comparison data
    stack = get_output_stack(spec_name=species_name, output=output_data)
    species_comparison_data = {}
    for simulator_name in stack.keys():
        row = stack[simulator_name]
        if row is None:
            simulators.remove(simulator_name)
        else:
            species_comparison_data[simulator_name] = row
    vals = list(species_comparison_data.values())
    valid_sims = list(species_comparison_data.keys())
    outputs = vals 
    methods = ['mse', 'proximity']
    if len(outputs) > 1:
        # outputs = _get_output_stack(output_data, species_name)
        matrix_vals = list(map(
            lambda m: self._generate_species_comparison_matrix(outputs=outputs, simulators=valid_sims, method=m, ground_truth=ground_truth, rtol=rTol, atol=aTol).to_dict(),
            methods
        ))
    else:
        matrix_vals = list(map(
            lambda m: {},
            methods
        ))

    results = dict(zip(methods, matrix_vals))
    results['output_data'] = {}
    data = None
    for simulator_name in output_data.keys():
        sim_output = output_data[simulator_name]
        for spec_name, spec_output in sim_output.items():
            print(f'Sim: {simulator_name} - Output Obs: {spec_name} - Current Obs Arg: {species_name}')
            if spec_name == species_name:
                data = output_data[simulator_name][spec_name]
            elif spec_name.lower() == 'error':
                data = output_data[simulator_name]
            results['output_data'][simulator_name] = data.tolist() if isinstance(data, np.ndarray) else data
    return results

# %%
import random 

obs_names = list(utc_outputs['copasi'].keys())
i = random.randint(0, len(obs_names) - 1)
self = w 
stack = get_output_stack(obs_names[i], utc_outputs)

# %%
s = ['copasi', 'tellurium']
comparisons = []
for obs in obs_names:
    comparison = _generate_omex_utc_species_comparison(self=w, output_data=utc_outputs, species_name=obs, simulators=s.copy())
    comparisons.append(comparison)
# Out:
# Sim: copasi - Output Obs: Time - Current Obs Arg: Time
# Sim: tellurium - Output Obs: error - Current Obs Arg: Time
# Sim: copasi - Output Obs: Time - Current Obs Arg: MAPK_PP
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MAPK_PP
# Sim: tellurium - Output Obs: error - Current Obs Arg: MAPK_PP
# Sim: copasi - Output Obs: Time - Current Obs Arg: MAPK
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MAPK
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: MAPK
# Sim: tellurium - Output Obs: error - Current Obs Arg: MAPK
# Sim: copasi - Output Obs: Time - Current Obs Arg: MKKK
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MKKK
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: MKKK
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: MKKK
# Sim: tellurium - Output Obs: error - Current Obs Arg: MKKK
# Sim: copasi - Output Obs: Time - Current Obs Arg: MKKK_P
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MKKK_P
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: MKKK_P
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: MKKK_P
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: MKKK_P
# Sim: tellurium - Output Obs: error - Current Obs Arg: MKKK_P
# Sim: copasi - Output Obs: Time - Current Obs Arg: MKK
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MKK
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: MKK
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: MKK
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: MKK
# Sim: copasi - Output Obs: MKK - Current Obs Arg: MKK
# Sim: tellurium - Output Obs: error - Current Obs Arg: MKK
# Sim: copasi - Output Obs: Time - Current Obs Arg: MKK_P
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MKK_P
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: MKK_P
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: MKK_P
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: MKK_P
# Sim: copasi - Output Obs: MKK - Current Obs Arg: MKK_P
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: MKK_P
# Sim: tellurium - Output Obs: error - Current Obs Arg: MKK_P
# Sim: copasi - Output Obs: Time - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: MKK - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: MKK_PP
# Sim: tellurium - Output Obs: error - Current Obs Arg: MKK_PP
# Sim: copasi - Output Obs: Time - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MKK - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: MAPK_P
# Sim: tellurium - Output Obs: error - Current Obs Arg: MAPK_P
# Sim: copasi - Output Obs: Time - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MKK - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: uVol
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: uVol
# Sim: copasi - Output Obs: uVol - Current Obs Arg: uVol
# Sim: tellurium - Output Obs: error - Current Obs Arg: uVol
# Sim: copasi - Output Obs: Time - Current Obs Arg: J0
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J0
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J0
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J0
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J0
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J0
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J0
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J0
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J0
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J0
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J0
# Sim: tellurium - Output Obs: error - Current Obs Arg: J0
# Sim: copasi - Output Obs: Time - Current Obs Arg: J1
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J1
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J1
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J1
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J1
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J1
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J1
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J1
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J1
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J1
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J1
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J1
# Sim: tellurium - Output Obs: error - Current Obs Arg: J1
# Sim: copasi - Output Obs: Time - Current Obs Arg: J2
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J2
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J2
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J2
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J2
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J2
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J2
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J2
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J2
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J2
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J2
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J2
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J2
# Sim: tellurium - Output Obs: error - Current Obs Arg: J2
# Sim: copasi - Output Obs: Time - Current Obs Arg: J3
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J3
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J3
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J3
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J3
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J3
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J3
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J3
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J3
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J3
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J3
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J3
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J3
# Sim: copasi - Output Obs: J3 - Current Obs Arg: J3
# Sim: tellurium - Output Obs: error - Current Obs Arg: J3
# Sim: copasi - Output Obs: Time - Current Obs Arg: J4
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J4
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J4
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J4
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J4
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J4
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J4
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J4
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J4
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J4
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J4
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J4
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J4
# Sim: copasi - Output Obs: J3 - Current Obs Arg: J4
# Sim: copasi - Output Obs: J4 - Current Obs Arg: J4
# Sim: tellurium - Output Obs: error - Current Obs Arg: J4
# Sim: copasi - Output Obs: Time - Current Obs Arg: J5
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J5
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J5
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J5
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J5
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J5
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J5
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J5
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J5
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J5
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J5
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J5
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J5
# Sim: copasi - Output Obs: J3 - Current Obs Arg: J5
# Sim: copasi - Output Obs: J4 - Current Obs Arg: J5
# Sim: copasi - Output Obs: J5 - Current Obs Arg: J5
# Sim: tellurium - Output Obs: error - Current Obs Arg: J5
# Sim: copasi - Output Obs: Time - Current Obs Arg: J6
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J6
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J6
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J6
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J6
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J6
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J6
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J6
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J6
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J6
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J6
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J6
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J6
# Sim: copasi - Output Obs: J3 - Current Obs Arg: J6
# Sim: copasi - Output Obs: J4 - Current Obs Arg: J6
# Sim: copasi - Output Obs: J5 - Current Obs Arg: J6
# Sim: copasi - Output Obs: J6 - Current Obs Arg: J6
# Sim: tellurium - Output Obs: error - Current Obs Arg: J6
# Sim: copasi - Output Obs: Time - Current Obs Arg: J7
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J7
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J7
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J7
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J7
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J7
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J7
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J7
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J7
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J7
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J7
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J7
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J7
# Sim: copasi - Output Obs: J3 - Current Obs Arg: J7
# Sim: copasi - Output Obs: J4 - Current Obs Arg: J7
# Sim: copasi - Output Obs: J5 - Current Obs Arg: J7
# Sim: copasi - Output Obs: J6 - Current Obs Arg: J7
# Sim: copasi - Output Obs: J7 - Current Obs Arg: J7
# Sim: tellurium - Output Obs: error - Current Obs Arg: J7
# Sim: copasi - Output Obs: Time - Current Obs Arg: J8
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J8
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J8
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J8
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J8
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J8
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J8
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J8
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J8
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J8
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J3 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J4 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J5 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J6 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J7 - Current Obs Arg: J8
# Sim: copasi - Output Obs: J8 - Current Obs Arg: J8
# Sim: tellurium - Output Obs: error - Current Obs Arg: J8
# Sim: copasi - Output Obs: Time - Current Obs Arg: J9
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: J9
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: J9
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: J9
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: J9
# Sim: copasi - Output Obs: MKK - Current Obs Arg: J9
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: J9
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: J9
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: J9
# Sim: copasi - Output Obs: uVol - Current Obs Arg: J9
# Sim: copasi - Output Obs: J0 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J1 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J2 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J3 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J4 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J5 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J6 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J7 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J8 - Current Obs Arg: J9
# Sim: copasi - Output Obs: J9 - Current Obs Arg: J9
# Sim: tellurium - Output Obs: error - Current Obs Arg: J9
# Sim: copasi - Output Obs: Time - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MKK - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: uVol - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J0 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J1 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J2 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J3 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J4 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J5 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J6 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J7 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J8 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: J9 - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: task_fig2a.time/60 - Current Obs Arg: task_fig2a.time/60
# Sim: tellurium - Output Obs: error - Current Obs Arg: task_fig2a.time/60
# Sim: copasi - Output Obs: Time - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MKK - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: uVol - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J0 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J1 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J2 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J3 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J4 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J5 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J6 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J7 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J8 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: J9 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: task_fig2a.time/60 - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: task_fig2b.time/60 - Current Obs Arg: task_fig2b.time/60
# Sim: tellurium - Output Obs: error - Current Obs Arg: task_fig2b.time/60
# Sim: copasi - Output Obs: Time - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MKK - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: uVol - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J0 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J1 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J2 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J3 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J4 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J5 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J6 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J7 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J8 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: J9 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: task_fig2a.time/60 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: task_fig2b.time/60 - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: task_fig2a.MAPK_PP - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: tellurium - Output Obs: error - Current Obs Arg: task_fig2a.MAPK_PP
# Sim: copasi - Output Obs: Time - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MKK - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: uVol - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J0 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J1 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J2 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J3 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J4 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J5 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J6 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J7 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J8 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: J9 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: task_fig2a.time/60 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: task_fig2b.time/60 - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: task_fig2a.MAPK_PP - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: task_fig2a.MAPK - Current Obs Arg: task_fig2a.MAPK
# Sim: tellurium - Output Obs: error - Current Obs Arg: task_fig2a.MAPK
# Sim: copasi - Output Obs: Time - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MKK - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: uVol - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J0 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J1 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J2 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J3 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J4 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J5 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J6 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J7 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J8 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: J9 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: task_fig2a.time/60 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: task_fig2b.time/60 - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: task_fig2a.MAPK_PP - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: task_fig2a.MAPK - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: task_fig2b.MAPK_PP - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: tellurium - Output Obs: error - Current Obs Arg: task_fig2b.MAPK_PP
# Sim: copasi - Output Obs: Time - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MAPK_PP - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MAPK - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MKKK - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MKKK_P - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MKK - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MKK_P - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MKK_PP - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: MAPK_P - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: uVol - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J0 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J1 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J2 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J3 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J4 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J5 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J6 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J7 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J8 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: J9 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: task_fig2a.time/60 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: task_fig2b.time/60 - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: task_fig2a.MAPK_PP - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: task_fig2a.MAPK - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: task_fig2b.MAPK_PP - Current Obs Arg: task_fig2b.MAPK
# Sim: copasi - Output Obs: task_fig2b.MAPK - Current Obs Arg: task_fig2b.MAPK
# Sim: tellurium - Output Obs: error - Current Obs Arg: task_fig2b.MAPK

# %%
comparisons
# Out:
# [{'mse': {}, 'proximity': {}, 'output_data': {}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}},
#  {'mse': {}, 'proximity': {}, 'output_data': {'copasi': None}}]

# %%
# conditions for successful comparison matrices: 
# A. All slices must be valid (non-string) -> the stack shape must be (n_simulators, n_steps)!
# B. Of all valid slices, AT LEAST two slices (simulator result slices) must be available
